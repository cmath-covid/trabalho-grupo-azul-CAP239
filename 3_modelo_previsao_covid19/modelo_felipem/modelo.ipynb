# %% [markdown]
# <div align="center">
#   <img src="logoinpe.png">
# </div>
#
#
# # Análise Estatística e Espectral de Processos Estocásticos (CAP-239-4)
#
# <hr>
#
# Docentes:
# - Dr. Reinaldo Rosa
# - Dr. Leonardo B. L. Santos
#
# Discentes:
#  - Fernando Cossetin;
#  - Felipe Menino Carlos;
#  - Felipe Perin.

# %% [markdown]
# ## Previsão de casos diários - COVID19
#
# Este documento apresenta o modelo de previsão do número de casos diários. Desenvolvido pelo Prof. Dr. Reinaldo Rosa

# %% [markdown]
# <hr>
#
# Este documento apresenta os resultados objetivos com a aplicação do modelo de previsão de casos diários de COVID-19. Esta é uma das implementações desenvolvidas neste trabalho. Abaixo o modelo é executado para os casos diários de cada um dos países e regiões analisados.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from covidmodeler import (
    covidmodeler, load_owd, generate_fiocruz_datamean,
    WeightSpectraCase1, WeightSpectraCase2, organize_data
)

# %% [markdown]
# Carregando os dados

# %%
data_owd = load_owd()

# %% [markdown]
# **Brasil - Peso espectral 1**

# %%
data_owd_brazil = data_owd[data_owd["iso_code"] == "BRA"]
data_owd_brazil = data_owd_brazil[data_owd_brazil.new_cases >= 50]
data_owd_brazil = generate_fiocruz_datamean(data_owd_brazil)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data_owd_brazil, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = True, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data_owd_brazil)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Brasil (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Brasil - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data_owd_brazil, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = True, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data_owd_brazil)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x, 
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Brasil (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Canadá - Peso espectral 1**

# %%
data = data_owd[data_owd["iso_code"] == "CAN"]
data = data[data.new_cases >= 50]
data = generate_fiocruz_datamean(data)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Canadá (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Canadá - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Canadá (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **México - Peso espectral 1**

# %%
data = data_owd[data_owd["iso_code"] == "MEX"]
data = data[data.new_cases >= 50]
data = generate_fiocruz_datamean(data)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = True, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o México (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **México - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = True, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o México (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Cuba - Peso espectral 1**

# %%
data = data_owd[data_owd["iso_code"] == "CUB"]
data = generate_fiocruz_datamean(data)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Cuba (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Cuba - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Cuba (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Rússia - Peso espectral 1**

# %%
data = data_owd[data_owd["iso_code"] == "RUS"]
data = generate_fiocruz_datamean(data)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Rússia (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Rússia - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para o Rússia (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Dados regionais
#
# Esta seção apresenta a aplicação do modelo em dados regionais, especificamente para o estado de Minais Gerais (MG) e Niterói

# %%
national = pd.read_csv('blueteam_national_update_2020_06_03.csv')

# %% [markdown]
# **Estado de Minas Gerais - Peso espectral 1**

# %%
data = national[national['state'] == 'MG']
data = data[data['place_type'] == 'state']
data.set_index('date', inplace = True)
data = data.sort_index()
data['new_cases'] = data.new_confirmed
data = generate_fiocruz_datamean(data)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para Minas Gerais (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Estado de Minas Gerais - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = False, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para Minas Gerais (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Niterói - Peso espectral 1**

# %%
data = national[national['state'] == 'RJ']
data.set_index('date', inplace = True)
data = data.sort_index()
idx = data[data.new_confirmed > 0].index
data = data.groupby(['date', 'state']).sum()
data = data[data.new_confirmed > 0]
data['new_cases'] = data.new_confirmed

data = pd.DataFrame({
    'new_cases': data.new_cases.values,
}, index = idx)
data = generate_fiocruz_datamean(data)

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase1, 
                             isIncomplete = True, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para Niterói (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Niterói - Peso espectral 2**

# %%
predictedvalues, generated_parameters, generated_supression_parameters = \
                covidmodeler(data, '2020-04-01', 20, WeightSpectraCase2, 
                             isIncomplete = True, usePredict = True)

prepared_data = organize_data(predictedvalues, generated_parameters, data)

plt.figure(dpi = 300)
plt.plot(prepared_data.index, prepared_data.fiocruz_mean, 'blue')
plt.fill_between(prepared_data.index, prepared_data.new_cases_x,
                     prepared_data.fiocruz_estimate, alpha = 0.3, edgecolor = 'red', facecolor = 'gray')
plt.plot(prepared_data.index, prepared_data.new_cases_y, 'green')
plt.fill_between(prepared_data.index, prepared_data.nmin, prepared_data.nmax, facecolor = 'orange')
plt.title("Previsão de casos para Niterói (01/04/2020 - 30/04/2020)")
plt.legend(["Dados estimados - Fiocruz", "Dados estimados - modelo"])
plt.xticks(rotation=45)
plt.show()
