# %% [markdown]
# <div align="center">
#   <img src="logoinpe.png">
# </div>
#
#
# # Análise Estatística e Espectral de Processos Estocásticos (CAP-239-4)
#
# <hr>
#
# Docentes:
# - Dr. Reinaldo Rosa
# - Dr. Leonardo B. L. Santos
#
# Discentes:
#  - Fernando Cossetin;
#  - Felipe Menino Carlos;
#  - Felipe Perin.

# %% [markdown]
# **Atividade**: Ajustes de Função de Densidade de Probabilidade (PDF)
#
# **Descrição da atividade**: Ajustar as melhores PDFs para cada um dos dados considerados neste trabalho. O ajuste deve ser feito somente para os dados de flutuação, uma vez que, a caracterização base já descreve o comportamento geral dos dados acumulados, que não possuem flutuações. Assim, as variáveis consideradas nesta atividade serão o `Número Diário de Casos (NDC)`, `Número Diário de Mortes (NDM)` e `Número Diário de Testes (NDT)`.

# %%
import scipy.stats
import numpy as np
import pandas as pd
from plotnine import *
from fitter import Fitter
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import warnings
warnings.filterwarnings("ignore")

# %%
data_owd = pd.read_csv('../1_conjunto_de_dados/dataset/data/blueteam_international_update_2020_06_03.csv')
data_owd['date'] = pd.to_datetime(data_owd['date'])

# %% [markdown]
# Para a realização do ajuste das PDFs de maneira automatizada será feita a utilização do pacote [fitter](https://fitter.readthedocs.io/en/latest/), que através de uma interface simples permite o teste e verificação de mais de 80 tipos de distribuições, essas providas pelo pacote [SciPy](https://www.scipy.org/).
#
# Abaixo as divisões são feitas considerandos cada um dos países analisados neste trabalho.

# %% [markdown]
# ### Brasil

# %%
bra = data_owd[data_owd['iso_code'] == 'BRA']

# %% [markdown]
# **Número de casos diários**

# %%
bra_newcases = bra[bra.new_cases >= 50].new_cases

# %%
f = Fitter(bra_newcases, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de mortes diárias**

# %%
bra_newdeaths = bra[bra.new_deaths >= 50].new_deaths

# %%
f = Fitter(bra_newdeaths, verbose = False, bins = 30)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de testes diários**

# %%
# Infelizmente não há testes suficientes para este ajuste

# %% [markdown]
# ### Canadá

# %%
can = data_owd[data_owd['iso_code'] == 'CAN']

# %% [markdown]
# **Número de casos diários**

# %%
can_newcases = can[can.new_cases >= 50].new_cases

# %%
f = Fitter(can_newcases, verbose = False, bins = 30)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de mortes diárias**

# %%
can_newdeaths = can[can.new_deaths >= 50].new_deaths

# %%
f = Fitter(can_newdeaths, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de testes diários**

# %%
can_newtests = can[can.new_tests >= 50].new_tests

# %%
f = Fitter(can_newtests, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# ### México

# %%
mex = data_owd[data_owd['iso_code'] == 'MEX']

# %% [markdown]
# **Número de casos diários**

# %%
mex_newcases = mex[mex.new_cases >= 50].new_cases

# %%
f = Fitter(mex_newcases, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de mortes diárias**

# %%
mex_newdeaths = mex[mex.new_deaths >= 50].new_deaths

# %%
f = Fitter(mex_newdeaths, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de testes diários**

# %%
mex_newtests = mex[mex.new_tests >= 50].new_tests

# %%
f = Fitter(can_newtests, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# ### Cuba

# %%
cub = data_owd[data_owd['iso_code'] == 'CUB']

# %% [markdown]
# **Número de casos diários**

# %%
cub_newcases = cub[cub.new_cases >= 50].new_cases

# %%
f = Fitter(cub_newcases, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de mortes diárias**

# %%
cub_newdeaths = cub.new_deaths

# %%
f = Fitter(cub_newdeaths, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de testes diários**

# %%
cub_newtests = cub[cub.new_tests >= 50].new_tests

# %%
f = Fitter(cub_newtests, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# ### Rússia

# %%
rus = data_owd[data_owd['iso_code'] == 'RUS']

# %% [markdown]
# **Número de casos diários**

# %%
rus_newcases = rus[rus.new_cases >= 50].new_cases

# %%
f = Fitter(rus_newcases, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de mortes diárias**

# %%
rus_newdeaths = rus[rus.new_deaths >= 50].new_deaths

# %%
f = Fitter(rus_newdeaths, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()

# %% [markdown]
# **Número de testes diários**

# %%
rus_newtests = rus[rus.new_tests >= 50].new_tests

# %%
f = Fitter(rus_newtests, verbose = False)
f.fit()
plt.figure(dpi = 150)
f.summary()
plt.show()
